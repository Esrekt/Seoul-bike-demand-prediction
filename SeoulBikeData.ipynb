# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("SeoulBikeData.csv", encoding="latin1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %%
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
df.columns.str.split()
# Out:
# Index([                           ['Date'],
#                ['Rented', 'Bike', 'Count'],
#                                   ['Hour'],
#                        ['Temperature(°C)'],
#                            ['Humidity(%)'],
#                 ['Wind', 'speed', '(m/s)'],
#                    ['Visibility', '(10m)'],
#        ['Dew', 'point', 'temperature(°C)'],
#          ['Solar', 'Radiation', '(MJ/m2)'],
#                           ['Rainfall(mm)'],
#                       ['Snowfall', '(cm)'],
#                                ['Seasons'],
#                                ['Holiday'],
#                     ['Functioning', 'Day']],
#       dtype='object')

# %%
df.columns=['Date','Rented_Bike_Count','Hour','Temperature','Humidity','Wind_speed','Visibility','Dew_point_temperature','Solar_Radiation','Rainfall','Snowfall','Seasons','Holiday','Functioning_Day']

# %%
df.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity',
#        'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
#        'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day'],
#       dtype='object')

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   8760 non-null   datetime64[ns]
#  1   Rented_Bike_Count      8760 non-null   int64
#  2   Hour                   8760 non-null   int64
#  3   Temperature            8760 non-null   float64
#  4   Humidity               8760 non-null   int64
#  5   Wind_speed             8760 non-null   float64
#  6   Visibility             8760 non-null   int64
#  7   Dew_point_temperature  8760 non-null   float64
#  8   Solar_Radiation        8760 non-null   float64
#  9   Rainfall               8760 non-null   float64
#  10  Snowfall               8760 non-null   float64
#  11  Seasons                8760 non-null   object
#  12  Holiday                8760 non-null   object
#  13  Functioning_Day        8760 non-null   object
# ...

# %%
df.head()
# Out:
#         Date  Rented_Bike_Count  Hour  Temperature  Humidity  Wind_speed  \
# 0 2017-01-12                254     0         -5.2        37         2.2
# 1 2017-01-12                204     1         -5.5        38         0.8
# 2 2017-01-12                173     2         -6.0        39         1.0
# 3 2017-01-12                107     3         -6.2        40         0.9
# 4 2017-01-12                 78     4         -6.0        36         2.3
#
#    Visibility  Dew_point_temperature  Solar_Radiation  Rainfall  Snowfall  \
# 0        2000                  -17.6              0.0       0.0       0.0
# 1        2000                  -17.6              0.0       0.0       0.0
# 2        2000                  -17.7              0.0       0.0       0.0
# 3        2000                  -17.6              0.0       0.0       0.0
# 4        2000                  -18.6              0.0       0.0       0.0
#
#   Seasons     Holiday Functioning_Day
# 0  Winter  No Holiday             Yes
# ...

# %%
df.duplicated().sum() #aynı geldiyse daha once false cıkar gelirse aynısı true
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                     0
# Rented_Bike_Count        0
# Hour                     0
# Temperature              0
# Humidity                 0
# Wind_speed               0
# Visibility               0
# Dew_point_temperature    0
# Solar_Radiation          0
# Rainfall                 0
# Snowfall                 0
# Seasons                  0
# Holiday                  0
# Functioning_Day          0
# dtype: int64

# %%
df["Rented_Bike_Count"].describe()
# Out:
# count    8760.000000
# mean      704.602055
# std       644.997468
# min         0.000000
# 25%       191.000000
# 50%       504.500000
# 75%      1065.250000
# max      3556.000000
# Name: Rented_Bike_Count, dtype: float64

# %%
#mean den sunu anlıyoruz saat bası ortalama 704 bisiklet kiralanıyor 
#std cok yuksek bu sepeble sunu anlıyoruz kiralama sayısı cok degisken
#saatlerin %25inde kiralama 191 den az

# %%
sns.histplot(df["Rented_Bike_Count"],bins=50)
plt.show()

# %%
df["Date"]
# Out:
# 0      2017-01-12
# 1      2017-01-12
# 2      2017-01-12
# 3      2017-01-12
# 4      2017-01-12
#           ...
# 8755   2018-11-30
# 8756   2018-11-30
# 8757   2018-11-30
# 8758   2018-11-30
# 8759   2018-11-30
# Name: Date, Length: 8760, dtype: datetime64[ns]

# %%
df["Year"]=df["Date"].dt.year
df["Month"]=df["Date"].dt.month
df["Day"]=df["Date"].dt.day
df["Weekday"]=df["Date"].dt.weekday

# %%
df.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity',
#        'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
#        'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day', 'Year',
#        'Month', 'Day', 'Weekday'],
#       dtype='object')

# %%
df["Date"]
# Out:
# 0      2017-01-12
# 1      2017-01-12
# 2      2017-01-12
# 3      2017-01-12
# 4      2017-01-12
#           ...
# 8755   2018-11-30
# 8756   2018-11-30
# 8757   2018-11-30
# 8758   2018-11-30
# 8759   2018-11-30
# Name: Date, Length: 8760, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity',
#        'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
#        'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day', 'Year',
#        'Month', 'Day', 'Weekday'],
#       dtype='object')

# %%
sns.boxplot(x="Month",y="Rented_Bike_Count",data=df)
plt.show()

# %%
sns.boxplot(x="Seasons",y="Rented_Bike_Count",data=df)
plt.show()

# %%
sns.boxplot(x="Holiday",y="Rented_Bike_Count",data=df)
plt.show()

# %%
sns.scatterplot(x="Temperature",y="Rented_Bike_Count",data=df)
plt.show()

# %%
num_cols = ["Temperature", "Humidity", "Wind_speed", "Visibility",
            "Dew_point_temperature", "Solar_Radiation", "Rainfall", "Snowfall"]
for col in num_cols:
    sns.scatterplot(x=df[col],y=df["Rented_Bike_Count"])
    plt.title(col)
    plt.show()

# %%
sns.boxplot(x="Hour",y="Rented_Bike_Count",data=df)
plt.show()

# %%
#hava zaman durum bilgilerine bakarak saatlik bisiklet kiralama sayısını tahmin edeceğiz

# %%
X = df[
    [
        "Hour",
        "Temperature",
        "Humidity",
        "Wind_speed",
        "Visibility",
        "Dew_point_temperature",
        "Solar_Radiation",
        "Rainfall",
        "Snowfall",
        "Seasons",
        "Holiday",
        "Functioning_Day"
    ]
]

# %%
y=df["Rented_Bike_Count"]

# %%
X = pd.get_dummies(
    X,
    columns=["Seasons", "Holiday", "Functioning_Day"],
    drop_first=True
)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(
X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
reg=LinearRegression()
reg.fit(X_train_scaled,y_train)
y_pred=reg.predict(X_test_scaled)
print("MAE:",mean_absolute_error(y_test,y_pred))
print("R2",r2_score(y_test,y_pred))
# Out:
# MAE: 327.60315337736824
# R2 0.5317774761182499

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("RF MAE:", mean_absolute_error(y_test, y_pred_rf))
print("RF R2 :", r2_score(y_test, y_pred_rf))
# Out:
# RF MAE: 143.95723744292238
# RF R2 : 0.8592390907906042

# %%
plt.scatter(y_test, y_pred_rf)
plt.xlabel("Gerçek")
plt.ylabel("Tahmin")
plt.show()

# %%
#diagonal cizginin etrafında genel olarak toplanmıs bu iyi sadece uc degeeler alakasız yerlerde kalmıs
